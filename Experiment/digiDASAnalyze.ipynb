# %%
#clear all varaibles
# %reset

# %%
# Basic packages
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from scipy.signal import find_peaks, peak_widths

#plt.rcParams['figure.dpi'] = 200
import os # for grabbing all files in folder

# For importing data as a R-like dataframe
import pandas as pd               

# Makes some plots look nicer
plt.style.use('ggplot')  # Set plot style

# %%
# load text files

df_Am241Back = pd.read_table("/Users/Sidious/Sync/Mac/JacobBaxley/2024_12_21/Am241_BackChamber_30min.txt", sep="\t")
df_Am241Front = pd.read_table("/Users/Sidious/Sync/Mac/JacobBaxley/2024_12_21/Am241_FrontChamber_30min.txt", sep="\t")
df_BP_660_Run_2_8936 = pd.read_table("/Users/Sidious/Sync/Mac/JacobBaxley/2024_12_21/BP_660_Run_2_8936.txt", sep="\t")
df_HeB_660_Run1_142 = pd.read_table("/Users/Sidious/Sync/Mac/JacobBaxley/2024_12_21/HeB_660_Run1_142.txt", sep="\t")

# %%
df = df_Am241Back;
bin_edges = np.arange(min(df.Energy),max(df.Energy));
det_0 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'A')].Energy
det_1 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'C')].Energy
det_2 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'A')].Energy
det_3 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'C')].Energy
det_4 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'D')].Energy
det_5 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'B')].Energy
det_6 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'D')].Energy
det_7 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'B')].Energy

# %%
df
# Out:
#         ADQ412# Channel           Time  EnergyOverflow  PulseSaturation  \
# 0             0       C       69805017           False            False
# 1             0       C       69806405           False            False
# 2             0       C       69807649           False            False
# 3             0       C       85614655           False            False
# 4             0       C       85615790           False            False
# ...         ...     ...            ...             ...              ...
# 161403        1       A  1621664751393           False            False
# 161404        1       D  1621664822931           False            False
# 161405        1       D  1621669264379           False            False
# 161406        1       D  1621669312941           False            False
# 161407        1       D  1621669316845           False            False
#
#         Energy  X  Y  Pile-upEvent  Pile-upCounter
# 0          829  0  0          True               1
# ...

# %%
fig, ax = plt.subplots(4,2, sharey=True, sharex=True, figsize=(10, 12))
ax[0,0].hist(det_0,bins=bin_edges,label="det_0",log =True);
ax[0,0].set_title('det_0')

ax[0,1].hist(det_1,bins=bin_edges,label="det_1");
ax[0,1].set_title('det_1')

ax[1,0].hist(det_2,bins=bin_edges,label="det_2");
ax[1,0].set_title('det_2')

ax[1,1].hist(det_3,bins=bin_edges,label="det_3");
ax[1,1].set_title('det_3')

ax[2,0].hist(det_4,bins=bin_edges,label="det_4");
ax[2,0].set_title('det_4')

ax[2,1].hist(det_5,bins=bin_edges,label="det_5");
ax[2,1].set_title('det_5')

ax[3,0].hist(det_6,bins=bin_edges,label="det_6");
ax[3,0].set_title('det_6')

ax[3,1].hist(det_7,bins=bin_edges,label="det_7");
ax[3,1].set_title('det_7')

#ax.legend()
#ax[1].set_xlabel('En')
#ax[1].set_ylabel('Count')
plt.show()

# %%
fig, ax = plt.subplots(4,2, sharey=True, sharex=True, figsize=(10, 12))
ax[0,0].hist(det_0,bins=bin_edges,label="det_0",log =False);
ax[0,0].set_title('det_0')

ax[0,1].hist(det_1,bins=bin_edges,label="det_1");
ax[0,1].set_title('det_1')

ax[1,0].hist(det_2,bins=bin_edges,label="det_2");
ax[1,0].set_title('det_2')

ax[1,1].hist(det_3,bins=bin_edges,label="det_3");
ax[1,1].set_title('det_3')

ax[2,0].hist(det_4,bins=bin_edges,label="det_4");
ax[2,0].set_title('det_4')

ax[2,1].hist(det_5,bins=bin_edges,label="det_5");
ax[2,1].set_title('det_5')

ax[3,0].hist(det_6,bins=bin_edges,label="det_6");
ax[3,0].set_title('det_6')

ax[3,1].hist(det_7,bins=bin_edges,label="det_7");
ax[3,1].set_title('det_7')

#ax.legend()
#ax[1].set_xlabel('En')
#ax[1].set_ylabel('Count')
plt.show()

# %%
df = df_Am241Front;
bin_edges = np.arange(min(df.Energy),max(df.Energy));
det_0 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'A')].Energy
det_1 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'C')].Energy
det_2 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'A')].Energy
det_3 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'C')].Energy
det_4 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'D')].Energy
det_5 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'B')].Energy
det_6 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'D')].Energy
det_7 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'B')].Energy

# %%
fig, ax = plt.subplots(4,2, sharey=True, sharex=True, figsize=(10, 12))
ax[0,0].hist(det_0,bins=bin_edges,label="det_0", log=True);
ax[0,0].set_title('det_0')

ax[0,1].hist(det_1,bins=bin_edges,label="det_1");
ax[0,1].set_title('det_1')

ax[1,0].hist(det_2,bins=bin_edges,label="det_2");
ax[1,0].set_title('det_2')

ax[1,1].hist(det_3,bins=bin_edges,label="det_3");
ax[1,1].set_title('det_3')

ax[2,0].hist(det_4,bins=bin_edges,label="det_4");
ax[2,0].set_title('det_4')

ax[2,1].hist(det_5,bins=bin_edges,label="det_5");
ax[2,1].set_title('det_5')

ax[3,0].hist(det_6,bins=bin_edges,label="det_6");
ax[3,0].set_title('det_6')

ax[3,1].hist(det_7,bins=bin_edges,label="det_7");
ax[3,1].set_title('det_7')

#ax.legend()
#ax[1].set_xlabel('En')
#ax[1].set_ylabel('Count')
plt.show()

# %%
fig, ax = plt.subplots(4,2, sharey=True, sharex=True, figsize=(10, 12))
ax[0,0].hist(det_0,bins=bin_edges,label="det_0", log=False);
ax[0,0].set_title('det_0')

ax[0,1].hist(det_1,bins=bin_edges,label="det_1");
ax[0,1].set_title('det_1')

ax[1,0].hist(det_2,bins=bin_edges,label="det_2");
ax[1,0].set_title('det_2')

ax[1,1].hist(det_3,bins=bin_edges,label="det_3");
ax[1,1].set_title('det_3')

ax[2,0].hist(det_4,bins=bin_edges,label="det_4");
ax[2,0].set_title('det_4')

ax[2,1].hist(det_5,bins=bin_edges,label="det_5");
ax[2,1].set_title('det_5')

ax[3,0].hist(det_6,bins=bin_edges,label="det_6");
ax[3,0].set_title('det_6')

ax[3,1].hist(det_7,bins=bin_edges,label="det_7");
ax[3,1].set_title('det_7')

#ax.legend()
#ax[1].set_xlabel('En')
#ax[1].set_ylabel('Count')
plt.show()

# %%
df = df_BP_660_Run_2_8936;
bin_edges = np.arange(min(df.Energy),max(df.Energy));
det_0 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'A')].Energy
det_1 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'C')].Energy
det_2 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'A')].Energy
det_3 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'C')].Energy
det_4 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'D')].Energy
det_5 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'B')].Energy
det_6 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'D')].Energy
det_7 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'B')].Energy

# %%
fig, ax = plt.subplots(4,2, sharey=True, sharex=True, figsize=(10, 12))
ax[0,0].hist(det_0,bins=bin_edges,label="det_0",log = True);
ax[0,0].set_title('det_0')

ax[0,1].hist(det_1,bins=bin_edges,label="det_1");
ax[0,1].set_title('det_1')

ax[1,0].hist(det_2,bins=bin_edges,label="det_2");
ax[1,0].set_title('det_2')

ax[1,1].hist(det_3,bins=bin_edges,label="det_3");
ax[1,1].set_title('det_3')

ax[2,0].hist(det_4,bins=bin_edges,label="det_4");
ax[2,0].set_title('det_4')

ax[2,1].hist(det_5,bins=bin_edges,label="det_5");
ax[2,1].set_title('det_5')

ax[3,0].hist(det_6,bins=bin_edges,label="det_6");
ax[3,0].set_title('det_6')

ax[3,1].hist(det_7,bins=bin_edges,label="det_7");
ax[3,1].set_title('det_7')

# rescale y axis with log

#ax.legend()
#ax[1].set_xlabel('En')
#ax[1].set_ylabel('Count')
plt.show()

# %%
fig, ax = plt.subplots(4,2, sharey=True, sharex=True, figsize=(10, 12))
ax[0,0].hist(det_0,bins=bin_edges,label="det_0",log = False);
ax[0,0].set_title('det_0')

ax[0,1].hist(det_1,bins=bin_edges,label="det_1");
ax[0,1].set_title('det_1')

ax[1,0].hist(det_2,bins=bin_edges,label="det_2");
ax[1,0].set_title('det_2')

ax[1,1].hist(det_3,bins=bin_edges,label="det_3");
ax[1,1].set_title('det_3')

ax[2,0].hist(det_4,bins=bin_edges,label="det_4");
ax[2,0].set_title('det_4')

ax[2,1].hist(det_5,bins=bin_edges,label="det_5");
ax[2,1].set_title('det_5')

ax[3,0].hist(det_6,bins=bin_edges,label="det_6");
ax[3,0].set_title('det_6')

ax[3,1].hist(det_7,bins=bin_edges,label="det_7");
ax[3,1].set_title('det_7')

# rescale y axis with log

#ax.legend()
#ax[1].set_xlabel('En')
#ax[1].set_ylabel('Count')
plt.show()

# %%
df = df_HeB_660_Run1_142;
bin_edges = np.arange(min(df.Energy),max(df.Energy));
det_0 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'A')].Energy
det_1 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'C')].Energy
det_2 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'A')].Energy
det_3 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'C')].Energy
det_4 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'D')].Energy
det_5 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'B')].Energy
det_6 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'D')].Energy
det_7 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'B')].Energy

# %%
fig, ax = plt.subplots(4,2, sharey=True, sharex=True, figsize=(10, 12))
ax[0,0].hist(det_0,bins=bin_edges,label="det_0", log = True);
ax[0,0].set_title('det_0')

ax[0,1].hist(det_1,bins=bin_edges,label="det_1");
ax[0,1].set_title('det_1')

ax[1,0].hist(det_2,bins=bin_edges,label="det_2");
ax[1,0].set_title('det_2')

ax[1,1].hist(det_3,bins=bin_edges,label="det_3");
ax[1,1].set_title('det_3')

ax[2,0].hist(det_4,bins=bin_edges,label="det_4");
ax[2,0].set_title('det_4')

ax[2,1].hist(det_5,bins=bin_edges,label="det_5");
ax[2,1].set_title('det_5')

ax[3,0].hist(det_6,bins=bin_edges,label="det_6");
ax[3,0].set_title('det_6')

ax[3,1].hist(det_7,bins=bin_edges,label="det_7");
ax[3,1].set_title('det_7')

# rescale y axis with log

#ax.legend()
#ax[1].set_xlabel('En')
#ax[1].set_ylabel('Count')
plt.show()

# %%
fig, ax = plt.subplots(4,2, sharey=True, sharex=True, figsize=(10, 12))
ax[0,0].hist(det_0,bins=bin_edges,label="det_0", log = False);
ax[0,0].set_title('det_0')

ax[0,1].hist(det_1,bins=bin_edges,label="det_1");
ax[0,1].set_title('det_1')

ax[1,0].hist(det_2,bins=bin_edges,label="det_2");
ax[1,0].set_title('det_2')

ax[1,1].hist(det_3,bins=bin_edges,label="det_3");
ax[1,1].set_title('det_3')

ax[2,0].hist(det_4,bins=bin_edges,label="det_4");
ax[2,0].set_title('det_4')

ax[2,1].hist(det_5,bins=bin_edges,label="det_5");
ax[2,1].set_title('det_5')

ax[3,0].hist(det_6,bins=bin_edges,label="det_6");
ax[3,0].set_title('det_6')

ax[3,1].hist(det_7,bins=bin_edges,label="det_7");
ax[3,1].set_title('det_7')

# rescale y axis with log

#ax.legend()
#ax[1].set_xlabel('En')
#ax[1].set_ylabel('Count')
plt.show()

# %%
def convert_to_cartesian_zx(r, theta):
    """
    Convert polar coordinates to Cartesian coordinates in a z-x plane.
    
    Args:
    r (float or array-like): radial distance from the origin
    theta (float or array-like): polar angle in degrees
    
    Returns:
    x (float or array-like): x-coordinate(s)
    y (float or array-like): y-coordinate(s)
    z (float or array-like): z-coordinate(s)
    """
    
    # Calculate the x-coordinate using sine function.
    x = r*np.sin(np.radians(theta))

    # Initialize y-coordinate with zeros.
    # This assumes a z-x plane where the y-coordinate is 0.
    if isinstance(theta, (list, tuple, np.ndarray)):
        y = np.zeros_like(theta)
    else:
        y = 0

    # Calculate the z-coordinate using cosine function.
    z = r*np.cos(np.radians(theta))

    # Return the x, y, and z coordinates.
    return x,y,z

def rotate_z(x, y, z, theta):
    """
    Rotate the given 3D points around the z-axis by the given angle.
    
    Args:
    x (numpy.ndarray): An array of x-coordinates of the 3D points.
    y (numpy.ndarray): An array of y-coordinates of the 3D points.
    z (numpy.ndarray): An array of z-coordinates of the 3D points.
    theta (float): The angle in degrees to rotate the points.
    
    Returns:
    tuple: A tuple of three numpy.ndarray objects representing the x, y, and z coordinates of the rotated points.
    """
    
    # Note this rotates cw staring at the x-y plane
    # Stack x, y, z along the first axis to create a (N, 3) shaped array `points`
    points = np.stack((x, y, z), axis=1)

    # Calculate the cosine and sine of the rotation angle `theta`
    cos_theta = np.cos(np.radians(theta))
    sin_theta = np.sin(np.radians(theta))

    # Create the rotation matrix around the z-axis
    # The shape of the rotation matrix is (3, 3, N) where N is the number of points
    rotation_matrix = np.stack((
        np.stack((cos_theta, -sin_theta, np.zeros_like(theta)), axis=1),
        np.stack((sin_theta, cos_theta, np.zeros_like(theta)), axis=1),
        np.stack((np.zeros_like(theta), np.zeros_like(theta), np.ones_like(theta)), axis=1)
    ), axis=2)

    # Perform matrix multiplication between the rotation matrix and the points
    rotated_points = np.matmul(rotation_matrix, points[:, :, np.newaxis])

    # Extract the rotated x, y, and z values from the rotated_points
    rx = rotated_points[:, 0, 0]
    ry = rotated_points[:, 1, 0]
    rz = rotated_points[:, 2, 0]

    # Return the rotated x, y, and z values
    return rx, ry, rz

# %%
#set up detectors
d = 2.61 # cm (2.61 cm) (Distance to the detector)

pL = d/np.sqrt(3)
detector_x = np.array([pL,pL,pL,pL,-pL,-pL,-pL,-pL])
detector_y = np.array([pL,-pL,pL,-pL,-pL,pL,-pL,pL])
detector_z = np.array([pL,pL,-pL,-pL,-pL,-pL,pL,pL])

detector_area = 0.13#.066 #cm^2 (2.4 mm * 2.8 mm)
r_detector = np.sqrt(detector_area/np.pi) #radius of detector assuming circle
min_angle = np.degrees(np.arctan(np.clip(r_detector/d,-1,1))) #minimum angle that will go into the detector

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

#detectors
ax.scatter3D(detector_x, detector_y, detector_z, c="blue")

det_num = ['(0)L1','(1)R2','(2)R4','(3)L3','(4)L4','(5)R3','(6)R1','(7)L2'] #np.arange(len(detector_x))

for x,y,z,s in zip(detector_x, detector_y, detector_z, det_num):
    ax.text(x, y, z, s)

# ax.plot3D([0, a10_x[0]], [0, a10_y[0]], [0, a10_z[0]], "green")
# ax.plot3D([0, Be_x[0]],[0, Be_y[0]],[0, Be_z[0]], "red")

# ax.plot3D([0, a11_x[0]],[0, a11_y[0]],[0, a11_z[0]], "orange")
# ax.plot3D([0, a12_x[0]],[0, a12_y[0]],[0, a12_z[0]], "pink")

# ax.scatter3D(rx, ry, rz, "green")
# ax.plot3D(rx, ry, rz, "green")

# ax.scatter3D(0, 0, 0, "red")

ax.plot3D([0,0],[0,0],[0,-max(detector_z)], "red")

ax.scatter3D(0,0,0, c="black")

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

ax.view_init(-140, 30)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
det_mat = np.stack((detector_x, detector_y, detector_z), axis=1)

# %%
det_mat
# Out:
# array([[ 1.5068842,  1.5068842,  1.5068842],
#        [ 1.5068842, -1.5068842,  1.5068842],
#        [ 1.5068842,  1.5068842, -1.5068842],
#        [ 1.5068842, -1.5068842, -1.5068842],
#        [-1.5068842, -1.5068842, -1.5068842],
#        [-1.5068842,  1.5068842, -1.5068842],
#        [-1.5068842, -1.5068842,  1.5068842],
#        [-1.5068842,  1.5068842,  1.5068842]])

# %% [markdown]
# | Detector Number | LeftRight | ADQ | channel | x-vect     | y-vect     | z-vect     |
# |-----------------|-----------|-----|---------|------------|------------|------------|
# | 0               | L1        | 0   | A       | 1.5068842  |  1.5068842 |  1.5068842 |
# | 1               | R2        | 1   | C       | 1.5068842  | -1.5068842 |  1.5068842 |
# | 2               | R4        | 1   | A       | 1.5068842  |  1.5068842 | -1.5068842 |
# | 3               | L3        | 0   | C       | 1.5068842  | -1.5068842 | -1.5068842 |
# | 4               | L4        | 0   | D       | -1.5068842 | -1.5068842 | -1.5068842 |
# | 5               | R3        | 1   | B       | -1.5068842 |  1.5068842 | -1.5068842 |
# | 6               | R1        | 1   | D       | -1.5068842 | -1.5068842 |  1.5068842 |
# | 7               | L2        | 0   | B       | -1.5068842 |  1.5068842 |  1.5068842 |

# %%
det_0 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'A')].Energy
det_1 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'C')].Energy
det_2 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'A')].Energy
det_3 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'C')].Energy
det_4 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'D')].Energy
det_5 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'B')].Energy
det_6 = df.loc[(df["ADQ412#"] == 1) & (df["Channel"] == 'D')].Energy
det_7 = df.loc[(df["ADQ412#"] == 0) & (df["Channel"] == 'B')].Energy

# %%
# alpha identifier function
# Can you run simnra with WINE?
